# %%
# import required libraries
from kafka import KafkaConsumer, KafkaProducer
import avro.schema
import avro.io
import io
import hashlib, json

# %%
def serialize(schema, obj):
    bytes_writer = io.BytesIO()
    encoder = avro.io.BinaryEncoder(bytes_writer)
    writer = avro.io.DatumWriter(schema)
    writer.write(obj, encoder)
    return bytes_writer.getvalue()

# %%
def deserialize(schema, raw_bytes):
    bytes_reader = io.BytesIO(raw_bytes)
    decoder = avro.io.BinaryDecoder(bytes_reader)
    reader = avro.io.DatumReader(schema)
    return reader.read(decoder)

# %%
schema_file = 'transaction.avsc'
txschema = avro.schema.parse(open(schema_file).read())
schema_file = 'submit.avsc'
submitschema = avro.schema.parse(open(schema_file).read())
schema_file = 'result.avsc'
resultschema = avro.schema.parse(open(schema_file).read())

# %%
# Connect to kafka broker running in your local host (docker). Change this to your kafka broker if needed
kafka_broker = 'lab.aimet.tech:9092'

# %%
producer = KafkaProducer(bootstrap_servers=[kafka_broker])

# %%
txconsumer = KafkaConsumer(
    'transaction',
     bootstrap_servers=[kafka_broker],
     enable_auto_commit=True,
     value_deserializer=lambda x: deserialize(txschema, x))
resultconsumer = KafkaConsumer(
    'result', 
     bootstrap_servers=[kafka_broker],
     enable_auto_commit=True,
     value_deserializer=lambda x: deserialize(resultschema, x))

# %%
def gen_signature(txid, payer, payee, amount, token):
    o = {'txid': txid, 'payer': payer, 'payee': payee, 'amount': amount, 'token': token}
    return hashlib.md5(json.dumps(o, sort_keys=True).encode('utf-8')).hexdigest()

# %% [markdown]
# # Assignment

# %%
def submit_verification(vid, txid, signature):
    submit_data = {
        'vid': vid,
        'txid': txid,
        'signature': signature
    }
    
    serialized_data = serialize(submitschema, submit_data)
    producer.send('submit', serialized_data)
    producer.flush()
    return True

# %%
VID = 'V878613'
TOKEN = 'c6f697f7d57d6cc9bed218454300ddcd'

# %%
for tx_message in txconsumer:
    tx_data = tx_message.value
    txid = tx_data['txid']
    payer = tx_data['payer']
    payee = tx_data['payee']
    amount = tx_data['amount']

    signature = gen_signature(txid, payer, payee, amount, TOKEN)
    submit_verification(VID, txid, signature)

    transaction_verification = False
    for message in resultconsumer:
        result = message.value
        if result['vid'] == VID and result['txid'] == txid:
            if result['code'] == '200' or result['code'] == 200:
                print(f"Transaction {txid} is OK")
                print(result)
                print('-'*50)
            else:
                print(f"Transaction {txid} is NOT OK with {result['code']}")
            break
# Out:
# Transaction TX05672 is OK
# {'timestamp': 1743922885, 'vid': 'V878613', 'txid': 'TX05672', 'checksum': '1c7ba407fad45ca154e6a1a4e0230c4d', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX05119 is OK
# {'timestamp': 1743922892, 'vid': 'V878613', 'txid': 'TX05119', 'checksum': '3a7c62ea2d9ae770e5ebfa12f5221793', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04519 is OK
# {'timestamp': 1743922898, 'vid': 'V878613', 'txid': 'TX04519', 'checksum': '42ff7ad89d3fb187aea3bc43af1c0792', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08806 is OK
# {'timestamp': 1743922908, 'vid': 'V878613', 'txid': 'TX08806', 'checksum': '9b96ae6ecc9ec874a055a4982fba5dba', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX02491 is OK
# {'timestamp': 1743922915, 'vid': 'V878613', 'txid': 'TX02491', 'checksum': 'fbdefbf7dfaf91a851cab17b60dd2907', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX05787 is OK
# {'timestamp': 1743922920, 'vid': 'V878613', 'txid': 'TX05787', 'checksum': 'e3344ab1d3b72910263f37be29cb73e5', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09907 is OK
# {'timestamp': 1743922927, 'vid': 'V878613', 'txid': 'TX09907', 'checksum': '6a7600ec2e93139c96421df223836d9b', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07105 is OK
# {'timestamp': 1743922936, 'vid': 'V878613', 'txid': 'TX07105', 'checksum': '264c7585a2014d5f57137b5e24d3171a', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08734 is OK
# {'timestamp': 1743922941, 'vid': 'V878613', 'txid': 'TX08734', 'checksum': '997454f9b5f5173e31186106a7393bdc', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06327 is OK
# {'timestamp': 1743922947, 'vid': 'V878613', 'txid': 'TX06327', 'checksum': 'e4aeb8231db7c27934ea3ed6f600cdd9', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07152 is OK
# {'timestamp': 1743922955, 'vid': 'V878613', 'txid': 'TX07152', 'checksum': '3e7df1d2d4231fa678341dae2f20cc12', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08609 is OK
# {'timestamp': 1743922965, 'vid': 'V878613', 'txid': 'TX08609', 'checksum': '7bb97e24f034db4cc75f36f5642ae2e1', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03241 is OK
# {'timestamp': 1743922975, 'vid': 'V878613', 'txid': 'TX03241', 'checksum': '27578dc726943c41134cf8b9f47f3582', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09693 is OK
# {'timestamp': 1743922985, 'vid': 'V878613', 'txid': 'TX09693', 'checksum': '543c943c1c3deb9658e0159bba9f7bd8', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX02918 is OK
# {'timestamp': 1743922991, 'vid': 'V878613', 'txid': 'TX02918', 'checksum': 'e897c5fae7898dd268d63a7053eb5411', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00135 is OK
# {'timestamp': 1743922999, 'vid': 'V878613', 'txid': 'TX00135', 'checksum': '791a4546347285a426ce274ba17cd248', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04883 is OK
# {'timestamp': 1743923007, 'vid': 'V878613', 'txid': 'TX04883', 'checksum': '6e3dc75b9f66de96e40ffdef768afaee', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01213 is OK
# {'timestamp': 1743923012, 'vid': 'V878613', 'txid': 'TX01213', 'checksum': 'e94f508c52f93c867692250d3c0bd35b', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01155 is OK
# {'timestamp': 1743923021, 'vid': 'V878613', 'txid': 'TX01155', 'checksum': '6ab5ade6da5101bb99964d1f04b042fb', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06685 is OK
# {'timestamp': 1743923030, 'vid': 'V878613', 'txid': 'TX06685', 'checksum': 'eaab7bae53082b48998cb1487357d624', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00589 is OK
# {'timestamp': 1743923035, 'vid': 'V878613', 'txid': 'TX00589', 'checksum': 'f154d1258372327d5ea3a61bff6d70e4', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03535 is OK
# {'timestamp': 1743923042, 'vid': 'V878613', 'txid': 'TX03535', 'checksum': '7996b688046f098b3591a612e9226a44', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09964 is OK
# {'timestamp': 1743923049, 'vid': 'V878613', 'txid': 'TX09964', 'checksum': '5da1e4171ec926ce2bb7bac4a5a0aec1', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09087 is OK
# {'timestamp': 1743923055, 'vid': 'V878613', 'txid': 'TX09087', 'checksum': '1a84b6ca8f69223ba9ebfa1f60509c34', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08650 is OK
# {'timestamp': 1743923064, 'vid': 'V878613', 'txid': 'TX08650', 'checksum': 'a9c2e131e5d2e3930be28853a9d5e90b', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01857 is OK
# {'timestamp': 1743923070, 'vid': 'V878613', 'txid': 'TX01857', 'checksum': '56da0cea8a52be8ab2b4eb90e0d599b8', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX05682 is OK
# {'timestamp': 1743923075, 'vid': 'V878613', 'txid': 'TX05682', 'checksum': '975cdbf3fa38f94198ae96b7f2b3cc62', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04279 is OK
# {'timestamp': 1743923084, 'vid': 'V878613', 'txid': 'TX04279', 'checksum': '73e455f2b8ab7cb65c17f61be668ed42', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07232 is OK
# {'timestamp': 1743923093, 'vid': 'V878613', 'txid': 'TX07232', 'checksum': 'aff79a0cd081ab7c6a8bdf240c7feb12', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04388 is OK
# {'timestamp': 1743923100, 'vid': 'V878613', 'txid': 'TX04388', 'checksum': '5cd291c9946ef1412f298ced5c0c7cf1', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00469 is OK
# {'timestamp': 1743923109, 'vid': 'V878613', 'txid': 'TX00469', 'checksum': 'b2db95f199ae4889e57bec4e058dc3d6', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08686 is OK
# {'timestamp': 1743923119, 'vid': 'V878613', 'txid': 'TX08686', 'checksum': '1612d6f6c3551f8703b5d86bf8a52fa3', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09152 is OK
# {'timestamp': 1743923128, 'vid': 'V878613', 'txid': 'TX09152', 'checksum': 'fc44543e7460ef6d77e2815b876429eb', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX02525 is OK
# {'timestamp': 1743923134, 'vid': 'V878613', 'txid': 'TX02525', 'checksum': '2ea1752a28e1ad0b3f2f52c9aa003dc0', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01980 is OK
# {'timestamp': 1743923142, 'vid': 'V878613', 'txid': 'TX01980', 'checksum': '03cd2ed2f95ff9d3a44b484fa0655621', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06890 is OK
# {'timestamp': 1743923148, 'vid': 'V878613', 'txid': 'TX06890', 'checksum': 'c299a1d338c27438bbe11ee9825ee207', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06406 is OK
# {'timestamp': 1743923157, 'vid': 'V878613', 'txid': 'TX06406', 'checksum': '9755ffba73bda19f1f0608e9cd42182f', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04082 is OK
# {'timestamp': 1743923167, 'vid': 'V878613', 'txid': 'TX04082', 'checksum': '2b6ce099f260d16fd967b34bc5f09b30', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07842 is OK
# {'timestamp': 1743923172, 'vid': 'V878613', 'txid': 'TX07842', 'checksum': '38a73874436ae38da59fa99cc86bac88', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04072 is OK
# {'timestamp': 1743923177, 'vid': 'V878613', 'txid': 'TX04072', 'checksum': '4f8569e984d90016806cd2c8290ce03b', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07023 is OK
# {'timestamp': 1743923182, 'vid': 'V878613', 'txid': 'TX07023', 'checksum': '04048d52add6a12e79019160dd55b1be', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03541 is OK
# {'timestamp': 1743923187, 'vid': 'V878613', 'txid': 'TX03541', 'checksum': 'dd82f0331e241a6e88fad1ef7e27265f', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08029 is OK
# {'timestamp': 1743923193, 'vid': 'V878613', 'txid': 'TX08029', 'checksum': 'c51481eeb79513c6ebaf31cc19eb482c', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04951 is OK
# {'timestamp': 1743923199, 'vid': 'V878613', 'txid': 'TX04951', 'checksum': '0667caee33a36a9b0a51abc46e8029f6', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX02165 is OK
# {'timestamp': 1743923205, 'vid': 'V878613', 'txid': 'TX02165', 'checksum': '12eb3c139f8b925856bb690a9178b726', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07739 is OK
# {'timestamp': 1743923211, 'vid': 'V878613', 'txid': 'TX07739', 'checksum': '4953741a12bed7b796aea89d1e5baa4d', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX02407 is OK
# {'timestamp': 1743923218, 'vid': 'V878613', 'txid': 'TX02407', 'checksum': 'dcbfa00c051e4b4784badf0747dfd66c', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX02337 is OK
# {'timestamp': 1743923228, 'vid': 'V878613', 'txid': 'TX02337', 'checksum': 'a55616bb79173a8f5380dd0290f0efb6', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03201 is OK
# {'timestamp': 1743923235, 'vid': 'V878613', 'txid': 'TX03201', 'checksum': '23769132bd74d1b74b104f7217a25d45', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04792 is OK
# {'timestamp': 1743923244, 'vid': 'V878613', 'txid': 'TX04792', 'checksum': '84f25b496610454659aac3eb19e8763f', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00615 is OK
# {'timestamp': 1743923250, 'vid': 'V878613', 'txid': 'TX00615', 'checksum': 'e2ee89cdcfe70ac1f194fc447037bac7', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08365 is OK
# {'timestamp': 1743923259, 'vid': 'V878613', 'txid': 'TX08365', 'checksum': '5c2254e5a0ab791025986b189ff58ad6', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04267 is OK
# {'timestamp': 1743923264, 'vid': 'V878613', 'txid': 'TX04267', 'checksum': 'b3822458719eddb6f555cd39e2b85bac', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04207 is OK
# {'timestamp': 1743923272, 'vid': 'V878613', 'txid': 'TX04207', 'checksum': '7755d1c12fb8418e79ca9a7b839f5986', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04639 is OK
# {'timestamp': 1743923278, 'vid': 'V878613', 'txid': 'TX04639', 'checksum': '760c34a624f2f986e36d8a9bd0472bbb', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00849 is OK
# {'timestamp': 1743923287, 'vid': 'V878613', 'txid': 'TX00849', 'checksum': '82908cee8c188c745f884ed9a5fdd3f6', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03660 is OK
# {'timestamp': 1743923292, 'vid': 'V878613', 'txid': 'TX03660', 'checksum': '840460bb50728f7357a91711183628d1', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00831 is OK
# {'timestamp': 1743923300, 'vid': 'V878613', 'txid': 'TX00831', 'checksum': '6df37d6446dba704aca9ecb4218892a3', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08820 is OK
# {'timestamp': 1743923306, 'vid': 'V878613', 'txid': 'TX08820', 'checksum': 'deb8b4d17088cf76eefed80951b9c9b4', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX02586 is OK
# {'timestamp': 1743923316, 'vid': 'V878613', 'txid': 'TX02586', 'checksum': '330fedade2576a7886dfe8b4d3a1e54d', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX02033 is OK
# {'timestamp': 1743923324, 'vid': 'V878613', 'txid': 'TX02033', 'checksum': 'f8ee6a17915f6d93f4ab18f1c0c4a237', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX05636 is OK
# {'timestamp': 1743923332, 'vid': 'V878613', 'txid': 'TX05636', 'checksum': '1fed097d4e934d600ec0cf55b7e90fd3', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03737 is OK
# {'timestamp': 1743923341, 'vid': 'V878613', 'txid': 'TX03737', 'checksum': '7cb4869b6df227af6f5d861d6f7c5cb2', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08289 is OK
# {'timestamp': 1743923351, 'vid': 'V878613', 'txid': 'TX08289', 'checksum': '23a3500a62f2e65a38b4787b03248749', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04551 is OK
# {'timestamp': 1743923361, 'vid': 'V878613', 'txid': 'TX04551', 'checksum': 'efcd4e336e1d0f4c8676fb85b40bba90', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04684 is OK
# {'timestamp': 1743923369, 'vid': 'V878613', 'txid': 'TX04684', 'checksum': 'daf1fdb2db6bc1c1fda43e1ca48d7cb2', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06106 is OK
# {'timestamp': 1743923374, 'vid': 'V878613', 'txid': 'TX06106', 'checksum': 'e81bacfa0d48b4d6d027afdd7d3fd85e', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07710 is OK
# {'timestamp': 1743923383, 'vid': 'V878613', 'txid': 'TX07710', 'checksum': '7b38b28f4052649e3d775f8d8783918c', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04291 is OK
# {'timestamp': 1743923390, 'vid': 'V878613', 'txid': 'TX04291', 'checksum': '6e7dbe77079dfa6147ea2c15ae459533', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00903 is OK
# {'timestamp': 1743923399, 'vid': 'V878613', 'txid': 'TX00903', 'checksum': 'd4441d7550668e5a03929f79d799cf4e', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01697 is OK
# {'timestamp': 1743923407, 'vid': 'V878613', 'txid': 'TX01697', 'checksum': '02c753b41f51ccdd55ab7e2c2ced2486', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03327 is OK
# {'timestamp': 1743923414, 'vid': 'V878613', 'txid': 'TX03327', 'checksum': '7ed48c9490990d8b6288f87abbac73b0', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09187 is OK
# {'timestamp': 1743923420, 'vid': 'V878613', 'txid': 'TX09187', 'checksum': '759820b23c9df03ff0f0cd4c1bc1de15', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07725 is OK
# {'timestamp': 1743923430, 'vid': 'V878613', 'txid': 'TX07725', 'checksum': 'ce43c605659295b6d4849e2db738e189', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04951 is OK
# {'timestamp': 1743923438, 'vid': 'V878613', 'txid': 'TX04951', 'checksum': '0667caee33a36a9b0a51abc46e8029f6', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01486 is OK
# {'timestamp': 1743923443, 'vid': 'V878613', 'txid': 'TX01486', 'checksum': '3d7106c0ac4a7f8b3f17f79a4abd79ab', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01014 is OK
# {'timestamp': 1743923448, 'vid': 'V878613', 'txid': 'TX01014', 'checksum': '9bd5a52ff4fe7da754d04df9c368557b', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06095 is OK
# {'timestamp': 1743923453, 'vid': 'V878613', 'txid': 'TX06095', 'checksum': 'a06618cb67189e25ace5175b60c71d6d', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04953 is OK
# {'timestamp': 1743923462, 'vid': 'V878613', 'txid': 'TX04953', 'checksum': '3f1337d136391725b8edbcf0fa44c86f', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX05028 is OK
# {'timestamp': 1743923472, 'vid': 'V878613', 'txid': 'TX05028', 'checksum': '424c7026ae33a4cb5c7928d40f77430c', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03065 is OK
# {'timestamp': 1743923480, 'vid': 'V878613', 'txid': 'TX03065', 'checksum': '1ea0584d70f3aea4eab8fa11c5f33396', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX02254 is OK
# {'timestamp': 1743923489, 'vid': 'V878613', 'txid': 'TX02254', 'checksum': '056de8b9be1e71ea2977c65d3e5ea0f5', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09444 is OK
# {'timestamp': 1743923497, 'vid': 'V878613', 'txid': 'TX09444', 'checksum': '800e2ca6940f030a98e325509fbf76f7', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08208 is OK
# {'timestamp': 1743923502, 'vid': 'V878613', 'txid': 'TX08208', 'checksum': '39cfb75ce551671007082d33774b9fad', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09976 is OK
# {'timestamp': 1743923512, 'vid': 'V878613', 'txid': 'TX09976', 'checksum': '5dc8454c9dfad3c298f945cdec602c04', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01643 is OK
# {'timestamp': 1743923518, 'vid': 'V878613', 'txid': 'TX01643', 'checksum': 'ed2ec1b4093e894e0713f2d4cd95168b', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01730 is OK
# {'timestamp': 1743923524, 'vid': 'V878613', 'txid': 'TX01730', 'checksum': 'f117cefdfbd7d45dd946fd55e526352c', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08923 is OK
# {'timestamp': 1743923530, 'vid': 'V878613', 'txid': 'TX08923', 'checksum': '457aef64192f9d30b58b368871fa6a3f', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01125 is OK
# {'timestamp': 1743923537, 'vid': 'V878613', 'txid': 'TX01125', 'checksum': 'b37d9c7b0c26c53f5e242c522be1e043', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06302 is OK
# {'timestamp': 1743923543, 'vid': 'V878613', 'txid': 'TX06302', 'checksum': '0ae27cad90cb8a776df02cd6978c704c', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03900 is OK
# {'timestamp': 1743923548, 'vid': 'V878613', 'txid': 'TX03900', 'checksum': '1db17469b33a4ee1acd01ee41c6114c4', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX05622 is OK
# {'timestamp': 1743923558, 'vid': 'V878613', 'txid': 'TX05622', 'checksum': '5ed0b3c0fb5c022657ca3a04a7efc925', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04978 is OK
# {'timestamp': 1743923567, 'vid': 'V878613', 'txid': 'TX04978', 'checksum': 'f804131cd1c6326c5902823c37839b42', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07609 is OK
# {'timestamp': 1743923574, 'vid': 'V878613', 'txid': 'TX07609', 'checksum': '66c8486dd616bc7fa3bea9e6e7ac060b', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01759 is OK
# {'timestamp': 1743923584, 'vid': 'V878613', 'txid': 'TX01759', 'checksum': '5e6e36622f132172a52cc894de9c391e', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08890 is OK
# {'timestamp': 1743923589, 'vid': 'V878613', 'txid': 'TX08890', 'checksum': '05840119db3afd54d91656e39bcafb43', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08635 is OK
# {'timestamp': 1743923598, 'vid': 'V878613', 'txid': 'TX08635', 'checksum': '495ab893a6cefb1f1a19dd68c41d713c', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX05675 is OK
# {'timestamp': 1743923605, 'vid': 'V878613', 'txid': 'TX05675', 'checksum': '8d2bc8b2473cdb963246dc330754ca32', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06424 is OK
# {'timestamp': 1743923610, 'vid': 'V878613', 'txid': 'TX06424', 'checksum': '45e17fe6395cc157c9b80e760da7e4d5', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06246 is OK
# {'timestamp': 1743923618, 'vid': 'V878613', 'txid': 'TX06246', 'checksum': 'e1326bd5cad49eb9ba0bf66490c41cba', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX05140 is OK
# {'timestamp': 1743923626, 'vid': 'V878613', 'txid': 'TX05140', 'checksum': 'f94fddf69d31e4fa4b7dad07727a6f0d', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01645 is OK
# {'timestamp': 1743923633, 'vid': 'V878613', 'txid': 'TX01645', 'checksum': '1c9956b339aab9fc97d16b1657909b54', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04545 is OK
# {'timestamp': 1743923638, 'vid': 'V878613', 'txid': 'TX04545', 'checksum': '206ecee0de6772cf99bf477513519e7e', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09488 is OK
# {'timestamp': 1743923647, 'vid': 'V878613', 'txid': 'TX09488', 'checksum': 'a52d897f18ae9d1df97f4d14783f6b61', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09912 is OK
# {'timestamp': 1743923655, 'vid': 'V878613', 'txid': 'TX09912', 'checksum': '6b5427bbf0de28980c1fe018e3877a4e', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07976 is OK
# {'timestamp': 1743923665, 'vid': 'V878613', 'txid': 'TX07976', 'checksum': 'ea5514d8d44d235dd6d43da5814c2987', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07448 is OK
# {'timestamp': 1743923671, 'vid': 'V878613', 'txid': 'TX07448', 'checksum': '47a799f7346c9fdd50907a390d711b67', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08351 is OK
# {'timestamp': 1743923681, 'vid': 'V878613', 'txid': 'TX08351', 'checksum': 'f9ea3d068c8efea2cb40a1b4ba8ecc1d', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX05879 is OK
# {'timestamp': 1743923688, 'vid': 'V878613', 'txid': 'TX05879', 'checksum': '72df7eef9dcd7b3c7e2f77dcbe31258a', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04783 is OK
# {'timestamp': 1743923695, 'vid': 'V878613', 'txid': 'TX04783', 'checksum': '16773bb10a01e1439d1550e01f79f268', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX02309 is OK
# {'timestamp': 1743923702, 'vid': 'V878613', 'txid': 'TX02309', 'checksum': 'b0ad0f8a90178316b2992ffdc807d503', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04694 is OK
# {'timestamp': 1743923710, 'vid': 'V878613', 'txid': 'TX04694', 'checksum': '78defe27167ab3efadf267c5f6f02e94', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09708 is OK
# {'timestamp': 1743923717, 'vid': 'V878613', 'txid': 'TX09708', 'checksum': '86c95eb93b61ab95a371c32811c1ea1a', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01974 is OK
# {'timestamp': 1743923724, 'vid': 'V878613', 'txid': 'TX01974', 'checksum': '1da0d735c1de3870a6e634ff06d348f9', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX02304 is OK
# {'timestamp': 1743923733, 'vid': 'V878613', 'txid': 'TX02304', 'checksum': '303ffbac3bf001bd2d995d4e49a54a3a', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07397 is OK
# {'timestamp': 1743923741, 'vid': 'V878613', 'txid': 'TX07397', 'checksum': 'eb6726a5b59a9180304e8e96c267fe06', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04725 is OK
# {'timestamp': 1743923750, 'vid': 'V878613', 'txid': 'TX04725', 'checksum': '866c5c3cff55b860f05839b0a4512dbb', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06353 is OK
# {'timestamp': 1743923760, 'vid': 'V878613', 'txid': 'TX06353', 'checksum': '5a9b6bde40b6c4de7ba01321298d1bda', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX05511 is OK
# {'timestamp': 1743923768, 'vid': 'V878613', 'txid': 'TX05511', 'checksum': 'be5e8f22ee29d65a586fc5f3b17061d4', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01644 is OK
# {'timestamp': 1743923773, 'vid': 'V878613', 'txid': 'TX01644', 'checksum': '7fa9afac429d62618f27241184e5c0b1', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04334 is OK
# {'timestamp': 1743923780, 'vid': 'V878613', 'txid': 'TX04334', 'checksum': '3a81327b3ebe6cf5e1975b196c15acb0', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04158 is OK
# {'timestamp': 1743923790, 'vid': 'V878613', 'txid': 'TX04158', 'checksum': '7b32acf1863cbf7c788a72c1d50a3f14', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09638 is OK
# {'timestamp': 1743923799, 'vid': 'V878613', 'txid': 'TX09638', 'checksum': '9b17c055c65cee82ca081846cc54f663', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00515 is OK
# {'timestamp': 1743923807, 'vid': 'V878613', 'txid': 'TX00515', 'checksum': 'bf1f6263ecf521f51162d5b016569e65', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09314 is OK
# {'timestamp': 1743923817, 'vid': 'V878613', 'txid': 'TX09314', 'checksum': 'd16507b5c254bed63ad6710ddd638038', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04942 is OK
# {'timestamp': 1743923823, 'vid': 'V878613', 'txid': 'TX04942', 'checksum': '4684dab26238f5b72b198809ac79d8be', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03776 is OK
# {'timestamp': 1743923831, 'vid': 'V878613', 'txid': 'TX03776', 'checksum': 'a62429061192bb2c9c4c2a4b1fa47025', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03849 is OK
# {'timestamp': 1743923837, 'vid': 'V878613', 'txid': 'TX03849', 'checksum': '7d45b3e084aa8d817fd5e78e0bb9d280', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06225 is OK
# {'timestamp': 1743923846, 'vid': 'V878613', 'txid': 'TX06225', 'checksum': 'c747d0bd76ba2b9f6d03750830e6ffec', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01548 is OK
# {'timestamp': 1743923853, 'vid': 'V878613', 'txid': 'TX01548', 'checksum': '2a457e8724055481dbc636de49969215', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03719 is OK
# {'timestamp': 1743923858, 'vid': 'V878613', 'txid': 'TX03719', 'checksum': 'afad8998b0b78543c16a37e8053202c9', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00340 is OK
# {'timestamp': 1743923865, 'vid': 'V878613', 'txid': 'TX00340', 'checksum': 'e97d0ec49c69d7983a80530c573c7b1d', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07593 is OK
# {'timestamp': 1743923873, 'vid': 'V878613', 'txid': 'TX07593', 'checksum': 'a1bed4b8fee8992834f6fe876aaf4218', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08606 is OK
# {'timestamp': 1743923881, 'vid': 'V878613', 'txid': 'TX08606', 'checksum': 'b5e3c7e854688da0ad568ee4c710326d', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07811 is OK
# {'timestamp': 1743923886, 'vid': 'V878613', 'txid': 'TX07811', 'checksum': '6daa87365ef657d589c213d09306fc5f', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08858 is OK
# {'timestamp': 1743923895, 'vid': 'V878613', 'txid': 'TX08858', 'checksum': '818adc05ca08be64dd09e3f8dfae5fd0', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03990 is OK
# {'timestamp': 1743923901, 'vid': 'V878613', 'txid': 'TX03990', 'checksum': '6a8006bb8795c57856627ea0f6495562', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03373 is OK
# {'timestamp': 1743923908, 'vid': 'V878613', 'txid': 'TX03373', 'checksum': 'c19e3939db6bf724f60ebfdecb167ada', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06984 is OK
# {'timestamp': 1743923918, 'vid': 'V878613', 'txid': 'TX06984', 'checksum': '9161c94539a264fa993bd79e3bc57495', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06016 is OK
# {'timestamp': 1743923923, 'vid': 'V878613', 'txid': 'TX06016', 'checksum': '31464dc965bc88ba93f67d1d5dda8062', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04456 is OK
# {'timestamp': 1743923933, 'vid': 'V878613', 'txid': 'TX04456', 'checksum': '42bc414210d5af87418323cccdbf21b6', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09232 is OK
# {'timestamp': 1743923943, 'vid': 'V878613', 'txid': 'TX09232', 'checksum': '2bc7b605346a0fe33a5d0edc1d81468a', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00594 is OK
# {'timestamp': 1743923949, 'vid': 'V878613', 'txid': 'TX00594', 'checksum': 'cd813cabd02e3680328e4c43a84b23dd', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08049 is OK
# {'timestamp': 1743923957, 'vid': 'V878613', 'txid': 'TX08049', 'checksum': 'ee6401ae83148dffc3e02af25bfc75fc', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07008 is OK
# {'timestamp': 1743923964, 'vid': 'V878613', 'txid': 'TX07008', 'checksum': '2dd1e1b49d2bd3ad90a863f227a876e7', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04393 is OK
# {'timestamp': 1743923971, 'vid': 'V878613', 'txid': 'TX04393', 'checksum': '940c8966ad0305ed109f5ae4f4003703', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04196 is OK
# {'timestamp': 1743923977, 'vid': 'V878613', 'txid': 'TX04196', 'checksum': '5c248b11353afbb4cbfc5e707780a3c5', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01874 is OK
# {'timestamp': 1743923982, 'vid': 'V878613', 'txid': 'TX01874', 'checksum': '6fe878794f3b177c3a9dc85087c41f2a', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX02807 is OK
# {'timestamp': 1743923988, 'vid': 'V878613', 'txid': 'TX02807', 'checksum': '974be3216bc228e58202bd762ea88060', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00653 is OK
# {'timestamp': 1743923998, 'vid': 'V878613', 'txid': 'TX00653', 'checksum': '8fde0c31194576eadd5511282367bb64', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00870 is OK
# {'timestamp': 1743924005, 'vid': 'V878613', 'txid': 'TX00870', 'checksum': 'e22bed2344863942143526412659b38e', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04154 is OK
# {'timestamp': 1743924014, 'vid': 'V878613', 'txid': 'TX04154', 'checksum': '8ddaf39fff895ff51ccea0785a58eea7', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07041 is OK
# {'timestamp': 1743924019, 'vid': 'V878613', 'txid': 'TX07041', 'checksum': 'f72a3c47a40648a568be0084302cf436', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00898 is OK
# {'timestamp': 1743924024, 'vid': 'V878613', 'txid': 'TX00898', 'checksum': '158862e5421810008d461737cfce9f78', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03798 is OK
# {'timestamp': 1743924032, 'vid': 'V878613', 'txid': 'TX03798', 'checksum': '3528092c59d424e4843410d49e905e1f', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07798 is OK
# {'timestamp': 1743924038, 'vid': 'V878613', 'txid': 'TX07798', 'checksum': '4fd398e6c7ee6f184dc6691b9aea7eed', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX05075 is OK
# {'timestamp': 1743924047, 'vid': 'V878613', 'txid': 'TX05075', 'checksum': '26509b8fd4b0bb29538280b0c820714a', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08788 is OK
# {'timestamp': 1743924057, 'vid': 'V878613', 'txid': 'TX08788', 'checksum': '797472db9bfe332b7a4a67bdb80e5bf9', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00774 is OK
# {'timestamp': 1743924066, 'vid': 'V878613', 'txid': 'TX00774', 'checksum': '0858620d58ccaca0e0d4587f330460d6', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX02817 is OK
# {'timestamp': 1743924071, 'vid': 'V878613', 'txid': 'TX02817', 'checksum': 'dc6881e147b17bd08b2b8cc1b2bb972e', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09949 is OK
# {'timestamp': 1743924079, 'vid': 'V878613', 'txid': 'TX09949', 'checksum': 'be4abf780666852dd596e744d948b991', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06493 is OK
# {'timestamp': 1743924088, 'vid': 'V878613', 'txid': 'TX06493', 'checksum': '82eeb7144d2908ab5e6a30c5b0ab1568', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04856 is OK
# {'timestamp': 1743924097, 'vid': 'V878613', 'txid': 'TX04856', 'checksum': '175e2695a96389b6587cfd658e9f5c5f', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07664 is OK
# {'timestamp': 1743924104, 'vid': 'V878613', 'txid': 'TX07664', 'checksum': '87093acd818210afd4264a318c5f291a', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09341 is OK
# {'timestamp': 1743924114, 'vid': 'V878613', 'txid': 'TX09341', 'checksum': 'd2e005b712418d57fa3f36ee2ff979e7', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX05680 is OK
# {'timestamp': 1743924123, 'vid': 'V878613', 'txid': 'TX05680', 'checksum': 'fb985392e1c1e2117469052702200a2b', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07649 is OK
# {'timestamp': 1743924130, 'vid': 'V878613', 'txid': 'TX07649', 'checksum': '086fa8151df3b20a9d63e6bc175878a4', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06315 is OK
# {'timestamp': 1743924141, 'vid': 'V878613', 'txid': 'TX06315', 'checksum': '57aa9a83f3e00c4328490aace29ce62b', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01742 is OK
# {'timestamp': 1743924145, 'vid': 'V878613', 'txid': 'TX01742', 'checksum': '8c6c51686d7a88219acf28af8a29a14e', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07749 is OK
# {'timestamp': 1743924151, 'vid': 'V878613', 'txid': 'TX07749', 'checksum': '9e8f5fd72f59ee85cfbedfcfbdfde3f0', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00339 is OK
# {'timestamp': 1743924157, 'vid': 'V878613', 'txid': 'TX00339', 'checksum': '197614f8f3cd5ff42c0e3d323eedfc30', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07536 is OK
# {'timestamp': 1743924164, 'vid': 'V878613', 'txid': 'TX07536', 'checksum': '6b12ec4f09357dd74db0af7c7acc5dcb', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06756 is OK
# {'timestamp': 1743924171, 'vid': 'V878613', 'txid': 'TX06756', 'checksum': '93279c784f07b9d39308b91a36e22295', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08280 is OK
# {'timestamp': 1743924176, 'vid': 'V878613', 'txid': 'TX08280', 'checksum': 'd5e9060e3ea2044c548fa06c31c4fe99', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06182 is OK
# {'timestamp': 1743924181, 'vid': 'V878613', 'txid': 'TX06182', 'checksum': 'cb1f6caba030e3d00332f1e0e36ff6aa', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04391 is OK
# {'timestamp': 1743924186, 'vid': 'V878613', 'txid': 'TX04391', 'checksum': '6f519686f18e4d0a8a1d725c374fbca7', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03543 is OK
# {'timestamp': 1743924192, 'vid': 'V878613', 'txid': 'TX03543', 'checksum': '030867fb6982e26f9978d4c025ff8d37', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01876 is OK
# {'timestamp': 1743924198, 'vid': 'V878613', 'txid': 'TX01876', 'checksum': '80187dad7029b0d24e1ef16181eb3161', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00804 is OK
# {'timestamp': 1743924205, 'vid': 'V878613', 'txid': 'TX00804', 'checksum': '92abd8c33bc8a60a0cea2a5ff5e414ab', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03042 is OK
# {'timestamp': 1743924213, 'vid': 'V878613', 'txid': 'TX03042', 'checksum': '158c2dc05b8b9fbf3f8407a5e2fb4069', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04790 is OK
# {'timestamp': 1743924218, 'vid': 'V878613', 'txid': 'TX04790', 'checksum': 'c5d4dee692d4f6de8a55785f2f4532e4', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03678 is OK
# {'timestamp': 1743924224, 'vid': 'V878613', 'txid': 'TX03678', 'checksum': 'cc462a2ae7d94b94188c20a0fd27534e', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX05809 is OK
# {'timestamp': 1743924231, 'vid': 'V878613', 'txid': 'TX05809', 'checksum': 'a2e5e2ff5c46466e13268a43cd7507c6', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX05865 is OK
# {'timestamp': 1743924237, 'vid': 'V878613', 'txid': 'TX05865', 'checksum': 'd7f8ab906858f5ef853c9f2c2e2c0b42', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09816 is OK
# {'timestamp': 1743924242, 'vid': 'V878613', 'txid': 'TX09816', 'checksum': 'e011cba4dc1444d0780973589da0b839', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04028 is OK
# {'timestamp': 1743924249, 'vid': 'V878613', 'txid': 'TX04028', 'checksum': '0d91eb7b9600ea4ef19d8c0a883bb056', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00084 is OK
# {'timestamp': 1743924257, 'vid': 'V878613', 'txid': 'TX00084', 'checksum': 'a3ea6a223f4a062d6e07451f0e3bdce5', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00459 is OK
# {'timestamp': 1743924263, 'vid': 'V878613', 'txid': 'TX00459', 'checksum': '1a55e723a9fab8482c4a51f5b2b4bd42', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08143 is OK
# {'timestamp': 1743924270, 'vid': 'V878613', 'txid': 'TX08143', 'checksum': 'efdf3e8476002832afa478090a26b029', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09396 is OK
# {'timestamp': 1743924278, 'vid': 'V878613', 'txid': 'TX09396', 'checksum': 'daf9b41cdb20a5d05a63d40ec6f3d6bd', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX05260 is OK
# {'timestamp': 1743924288, 'vid': 'V878613', 'txid': 'TX05260', 'checksum': '1861f104a30b559a140a993394f5b1e0', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX05450 is OK
# {'timestamp': 1743924295, 'vid': 'V878613', 'txid': 'TX05450', 'checksum': '0298fb836126b9809e9837087c72fd0c', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00596 is OK
# {'timestamp': 1743924300, 'vid': 'V878613', 'txid': 'TX00596', 'checksum': 'bbec98b9f92650c3bdd7861cf3cb8211', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04785 is OK
# {'timestamp': 1743924307, 'vid': 'V878613', 'txid': 'TX04785', 'checksum': '6d4824fd227a3f5b3a71b88bb3897960', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07285 is OK
# {'timestamp': 1743924312, 'vid': 'V878613', 'txid': 'TX07285', 'checksum': 'f198dcef8fc0276335111553d211f294', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00273 is OK
# {'timestamp': 1743924322, 'vid': 'V878613', 'txid': 'TX00273', 'checksum': '083a5711e16c5adc2b41a167f84acfb7', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06179 is OK
# {'timestamp': 1743924331, 'vid': 'V878613', 'txid': 'TX06179', 'checksum': '2a0174c5b9ec9e59c2315ac3ec8672d4', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00518 is OK
# {'timestamp': 1743924341, 'vid': 'V878613', 'txid': 'TX00518', 'checksum': '57025a7d325357b728d1c4d06ce8757f', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04704 is OK
# {'timestamp': 1743924349, 'vid': 'V878613', 'txid': 'TX04704', 'checksum': 'd9574a136b56943d901d6fd1e150bba1', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX02929 is OK
# {'timestamp': 1743924356, 'vid': 'V878613', 'txid': 'TX02929', 'checksum': '0b02a9821d86f5e96c650949fbbdf8ef', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX02485 is OK
# {'timestamp': 1743924365, 'vid': 'V878613', 'txid': 'TX02485', 'checksum': 'd99d017c63d32ea3cf2f56ed69d92278', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01512 is OK
# {'timestamp': 1743924372, 'vid': 'V878613', 'txid': 'TX01512', 'checksum': 'f611273f48a29fa7d54a162433982e30', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03619 is OK
# {'timestamp': 1743924381, 'vid': 'V878613', 'txid': 'TX03619', 'checksum': '06a8ac6df7394713a8c4f6a6e485d831', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX05457 is OK
# {'timestamp': 1743924388, 'vid': 'V878613', 'txid': 'TX05457', 'checksum': '48750d059348120148b8c49eb8565955', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07906 is OK
# {'timestamp': 1743924393, 'vid': 'V878613', 'txid': 'TX07906', 'checksum': 'f16d6c1164beb1e348156857e758452e', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08662 is OK
# {'timestamp': 1743924400, 'vid': 'V878613', 'txid': 'TX08662', 'checksum': '806e5cb1637a417184522ecdcb59abf2', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX02553 is OK
# {'timestamp': 1743924406, 'vid': 'V878613', 'txid': 'TX02553', 'checksum': '7a9f24e1e140d02efe6d5cfd5afb7301', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX05891 is OK
# {'timestamp': 1743924413, 'vid': 'V878613', 'txid': 'TX05891', 'checksum': '2a7e30963a53dbd854d81e63a80f96d2', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06866 is OK
# {'timestamp': 1743924421, 'vid': 'V878613', 'txid': 'TX06866', 'checksum': '83adc74ea4035a1c0b96d8247f733b80', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX05500 is OK
# {'timestamp': 1743924429, 'vid': 'V878613', 'txid': 'TX05500', 'checksum': 'd5fcf407d024b20105399779fdf19a20', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX02757 is OK
# {'timestamp': 1743924435, 'vid': 'V878613', 'txid': 'TX02757', 'checksum': '3ef69c77656cc9f6986f1bdb0dd195ec', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00257 is OK
# {'timestamp': 1743924444, 'vid': 'V878613', 'txid': 'TX00257', 'checksum': '949a2216899d01b6eed186bb519ad6b5', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04954 is OK
# {'timestamp': 1743924453, 'vid': 'V878613', 'txid': 'TX04954', 'checksum': 'a0b15ab52b6c7d272d5a00dbe6ec3ee9', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01592 is OK
# {'timestamp': 1743924458, 'vid': 'V878613', 'txid': 'TX01592', 'checksum': 'eff77e1ee93935acf8f261d8411f7011', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03229 is OK
# {'timestamp': 1743924467, 'vid': 'V878613', 'txid': 'TX03229', 'checksum': 'f7abb31242071f753793c215eaf577c3', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03814 is OK
# ...
# --------------------------------------------------
# Transaction TX09911 is OK
# {'timestamp': 1743925320, 'vid': 'V878613', 'txid': 'TX09911', 'checksum': 'ec7c19f5dcc9e64275a496f42f1cc6c7', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00945 is OK
# {'timestamp': 1743925330, 'vid': 'V878613', 'txid': 'TX00945', 'checksum': '27c2b5a427ec127930e134562c88a259', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03677 is OK
# {'timestamp': 1743925337, 'vid': 'V878613', 'txid': 'TX03677', 'checksum': '5232f1bce3c085f344153f6e9f88b399', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00576 is OK
# {'timestamp': 1743925344, 'vid': 'V878613', 'txid': 'TX00576', 'checksum': 'ae89c740f2137ef461f1096db9c349b0', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06982 is OK
# {'timestamp': 1743925353, 'vid': 'V878613', 'txid': 'TX06982', 'checksum': 'c6833fe850bfd5db4fd72c951d34a242', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09754 is OK
# {'timestamp': 1743925362, 'vid': 'V878613', 'txid': 'TX09754', 'checksum': '1f3a4dd7b048f707617b6f86a8f3af4f', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX05713 is OK
# {'timestamp': 1743925369, 'vid': 'V878613', 'txid': 'TX05713', 'checksum': 'a1787e06e9bc691b76a2ba8ba4dda954', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03783 is OK
# {'timestamp': 1743925376, 'vid': 'V878613', 'txid': 'TX03783', 'checksum': 'e9ab3d4e3b2dcad0d297fab941426445', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX05648 is OK
# {'timestamp': 1743925384, 'vid': 'V878613', 'txid': 'TX05648', 'checksum': 'd3a2e7c54bb462a6456c3ed4b154fbb7', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06454 is OK
# {'timestamp': 1743925392, 'vid': 'V878613', 'txid': 'TX06454', 'checksum': '1f234c4ff91a023ff4ef23a945355275', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03110 is OK
# {'timestamp': 1743925397, 'vid': 'V878613', 'txid': 'TX03110', 'checksum': '4c19c37bd6b7a38521b51b96f80fe43b', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06267 is OK
# {'timestamp': 1743925405, 'vid': 'V878613', 'txid': 'TX06267', 'checksum': '0c2c947862c29c00c85a050ce8835554', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04928 is OK
# {'timestamp': 1743925410, 'vid': 'V878613', 'txid': 'TX04928', 'checksum': '82e98125138169ba1883afafec65fb1a', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00334 is OK
# {'timestamp': 1743925416, 'vid': 'V878613', 'txid': 'TX00334', 'checksum': '7a9598fda34da6013f891ed186fa61b1', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX05426 is OK
# {'timestamp': 1743925423, 'vid': 'V878613', 'txid': 'TX05426', 'checksum': 'fec2bf1540abdfdff1e93f7299660a16', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07880 is OK
# {'timestamp': 1743925429, 'vid': 'V878613', 'txid': 'TX07880', 'checksum': '66c36715051e74489d50a08f5e046e39', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04832 is OK
# {'timestamp': 1743925434, 'vid': 'V878613', 'txid': 'TX04832', 'checksum': 'ec85ec254c4ed565b272b6b7f433819d', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08729 is OK
# {'timestamp': 1743925441, 'vid': 'V878613', 'txid': 'TX08729', 'checksum': '3ac41ecd82535343e5354e9d496efea2', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08835 is OK
# {'timestamp': 1743925450, 'vid': 'V878613', 'txid': 'TX08835', 'checksum': 'cc361e8922633cd5d1d8bd795209643c', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09595 is OK
# {'timestamp': 1743925460, 'vid': 'V878613', 'txid': 'TX09595', 'checksum': '9434c9e08aa4c591de7df3f75308f7c8', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01283 is OK
# {'timestamp': 1743925470, 'vid': 'V878613', 'txid': 'TX01283', 'checksum': '59a1131b0cf71d4028fef476ddffb152', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03548 is OK
# {'timestamp': 1743925475, 'vid': 'V878613', 'txid': 'TX03548', 'checksum': 'd18704fd3b0d17490daa17bd7aa68926', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06166 is OK
# {'timestamp': 1743925485, 'vid': 'V878613', 'txid': 'TX06166', 'checksum': '9778bf9750bce1a32c70d34f8bc1bc48', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07833 is OK
# {'timestamp': 1743925493, 'vid': 'V878613', 'txid': 'TX07833', 'checksum': '48ffc681673200dc4cc8d8a4aed57915', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX06345 is OK
# {'timestamp': 1743925499, 'vid': 'V878613', 'txid': 'TX06345', 'checksum': 'c86b1de7cc47d939662ac138adb1066e', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03700 is OK
# {'timestamp': 1743925509, 'vid': 'V878613', 'txid': 'TX03700', 'checksum': '59e3c01b5469973ea8cdb88c4b7b2bbd', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08192 is OK
# {'timestamp': 1743925515, 'vid': 'V878613', 'txid': 'TX08192', 'checksum': '87cf212b5c49fef193316919a65ef0c7', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09870 is OK
# {'timestamp': 1743925526, 'vid': 'V878613', 'txid': 'TX09870', 'checksum': '720383611126abb15063d97b60528514', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX02982 is OK
# {'timestamp': 1743925531, 'vid': 'V878613', 'txid': 'TX02982', 'checksum': 'eeb53ad5a744c334fd03304c3729e527', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09922 is OK
# {'timestamp': 1743925537, 'vid': 'V878613', 'txid': 'TX09922', 'checksum': '2750356dae81bca08226c42457324e3b', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08068 is OK
# {'timestamp': 1743925546, 'vid': 'V878613', 'txid': 'TX08068', 'checksum': '3be86364ff5012bbcda8dce4486264a7', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04505 is OK
# {'timestamp': 1743925554, 'vid': 'V878613', 'txid': 'TX04505', 'checksum': 'b02b5eeb30960319ace8fb9a47389069', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX02880 is OK
# {'timestamp': 1743925560, 'vid': 'V878613', 'txid': 'TX02880', 'checksum': '74168e3f9818ed2f074f38bbfe505ff8', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03144 is OK
# {'timestamp': 1743925571, 'vid': 'V878613', 'txid': 'TX03144', 'checksum': '39d2618bb113dd776186fcb438a148ee', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01802 is OK
# {'timestamp': 1743925578, 'vid': 'V878613', 'txid': 'TX01802', 'checksum': 'b655ba66cbb16f096c48f8600ec73761', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07119 is OK
# {'timestamp': 1743925584, 'vid': 'V878613', 'txid': 'TX07119', 'checksum': '6c141666b3fad2fa980421d18a5aa5d8', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00721 is OK
# {'timestamp': 1743925592, 'vid': 'V878613', 'txid': 'TX00721', 'checksum': '400afa5e6dba148e17314326157c29e0', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00171 is OK
# {'timestamp': 1743925600, 'vid': 'V878613', 'txid': 'TX00171', 'checksum': '69b9c141dc67c298b58566e9ef713e4c', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08204 is OK
# {'timestamp': 1743925609, 'vid': 'V878613', 'txid': 'TX08204', 'checksum': 'a0579411df0cc5488110a4c4495c597c', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07031 is OK
# {'timestamp': 1743925614, 'vid': 'V878613', 'txid': 'TX07031', 'checksum': 'c0ca8cbcae0ea663614a9e07279e2d92', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00166 is OK
# {'timestamp': 1743925622, 'vid': 'V878613', 'txid': 'TX00166', 'checksum': 'b0acf19584fe7c54e459de2d4b9c5521', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX01643 is OK
# {'timestamp': 1743925629, 'vid': 'V878613', 'txid': 'TX01643', 'checksum': 'ed2ec1b4093e894e0713f2d4cd95168b', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07854 is OK
# {'timestamp': 1743925634, 'vid': 'V878613', 'txid': 'TX07854', 'checksum': '54971f685229769a1cf18e9d6fa4aa9f', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08657 is OK
# {'timestamp': 1743925643, 'vid': 'V878613', 'txid': 'TX08657', 'checksum': '1b1eb6a0247b9ceb660b3bc60fec0d76', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX09774 is OK
# {'timestamp': 1743925652, 'vid': 'V878613', 'txid': 'TX09774', 'checksum': '9bf12d76a85c316fce50abca680b1fda', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX02958 is OK
# {'timestamp': 1743925658, 'vid': 'V878613', 'txid': 'TX02958', 'checksum': '3ffc7326eb2a7eecbe97c31f5c14b1f5', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08121 is OK
# {'timestamp': 1743925663, 'vid': 'V878613', 'txid': 'TX08121', 'checksum': 'c67f5dc6d7832250fc08bfe6d3221c49', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX08345 is OK
# {'timestamp': 1743925671, 'vid': 'V878613', 'txid': 'TX08345', 'checksum': '4a53b4bda5554ed30b85982b021ecaee', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03091 is OK
# {'timestamp': 1743925678, 'vid': 'V878613', 'txid': 'TX03091', 'checksum': '1ac4c21d0ba2dd2fc88f228bbca8b572', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX07182 is OK
# {'timestamp': 1743925688, 'vid': 'V878613', 'txid': 'TX07182', 'checksum': '6e5bcb820474e04bc94b08fd719e03c1', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04988 is OK
# {'timestamp': 1743925696, 'vid': 'V878613', 'txid': 'TX04988', 'checksum': '96d2f7e479eac3e20d6bb0950199c6ab', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00808 is OK
# {'timestamp': 1743925702, 'vid': 'V878613', 'txid': 'TX00808', 'checksum': '7c7052e226e9310b6e1845b2fb5fa9e9', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX03470 is OK
# {'timestamp': 1743925710, 'vid': 'V878613', 'txid': 'TX03470', 'checksum': '644a0f115ff81bcdabfe6d083e0428c7', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX00875 is OK
# {'timestamp': 1743925715, 'vid': 'V878613', 'txid': 'TX00875', 'checksum': '2a6b1d86adfaa7ea194b68f9b6126f3c', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# Transaction TX04963 is OK
# {'timestamp': 1743925725, 'vid': 'V878613', 'txid': 'TX04963', 'checksum': '18053e71541ab99cc70e14a975c1565f', 'code': 200, 'message': 'Confirm'}
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 for tx_message in txconsumer:
#       2     tx_data = tx_message.value
#       3     txid = tx_data['txid']
#
# File /opt/anaconda3/envs/dsde/lib/python3.12/site-packages/kafka/consumer/group.py:1180, in KafkaConsumer.__next__(self)
#    1178     self._iterator = self._message_generator_v2()
#    1179 try:
# -> 1180     return next(self._iterator)
#    1181 except StopIteration:
#    1182     self._iterator = None
#
# File /opt/anaconda3/envs/dsde/lib/python3.12/site-packages/kafka/consumer/group.py:1152, in KafkaConsumer._message_generator_v2(self)
#    1150 def _message_generator_v2(self):
#    1151     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1152     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1153     for tp, records in six.iteritems(record_map):
#    1154         # Generators are stateful, and it is possible that the tp / records
#    1155         # here may become stale during iteration -- i.e., we seek to a
#    1156         # different offset, pause consumption, or lose assignment.
#    1157         for record in records:
#    1158             # is_fetchable(tp) should handle assignment changes and offset
#    1159             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1160             # outer function destroying the existing iterator/generator
#    1161             # via self._iterator = None
#
# File /opt/anaconda3/envs/dsde/lib/python3.12/site-packages/kafka/consumer/group.py:688, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     686 inner_timeout_ms = timeout_ms_fn(timeout_ms, None)
#     687 while not self._closed:
# --> 688     records = self._poll_once(inner_timeout_ms(), max_records, update_offsets=update_offsets)
#     689     if records:
#     690         return records
#
# File /opt/anaconda3/envs/dsde/lib/python3.12/site-packages/kafka/consumer/group.py:731, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     728 if records:
#     729     return records
# --> 731 self._client.poll(timeout_ms=inner_timeout_ms(self._coordinator.time_to_next_poll() * 1000))
#     732 # after the long poll, we should check whether the group needs to rebalance
#     733 # prior to returning data so that the group can stabilize faster
#     734 if self._coordinator.need_rejoin():
#
# File /opt/anaconda3/envs/dsde/lib/python3.12/site-packages/kafka/client_async.py:684, in KafkaClient.poll(self, timeout_ms, future)
#     677         timeout = min(
#     678             user_timeout_ms,
#     679             metadata_timeout_ms,
#     680             idle_connection_timeout_ms,
#     681             request_timeout_ms)
#     682         timeout = max(0, timeout)  # avoid negative timeouts
# --> 684     self._poll(timeout / 1000)
#     686 # called without the lock to avoid deadlock potential
#     687 # if handlers need to acquire locks
#     688 responses.extend(self._fire_pending_completed_requests())
#
# File /opt/anaconda3/envs/dsde/lib/python3.12/site-packages/kafka/client_async.py:727, in KafkaClient._poll(self, timeout)
#     724 self._register_send_sockets()
#     726 start_select = time.time()
# --> 727 ready = self._selector.select(timeout)
#     728 end_select = time.time()
#     729 if self._sensors:
#
# File /opt/anaconda3/envs/dsde/lib/python3.12/selectors.py:566, in KqueueSelector.select(self, timeout)
#     564 ready = []
#     565 try:
# --> 566     kev_list = self._selector.control(None, max_ev, timeout)
#     567 except InterruptedError:
#     568     return ready
#
# KeyboardInterrupt:
